# %% [markdown]
# # Pandas

# %% [markdown]
# ## 학습내용
# - pandas 라이브러리 불러오기
# - CSV 읽기, 저장
#   - read_csv
#   - to_csv
# - 기본 EDA(탐색적 데이터 분석)
#   - head()
#   - shape
#   - info()
#   - describe()
#   - corr()
# - 데이터프레임과 시리즈
#   - 하나의 컬럼(피처) 선택
#   - 두개 이상의 컬럼(피처) 선택
#   - 카테고리별 카운트
# - 결측치 확인 및 처리
#   - 결측치 확인
#   - 결측치 처리
# - 범주형 데이터 처리
#
# <hr/>

# %% [markdown]
# ### pandas 불러오기

# %%
import pandas as pd

# %% [markdown]
# ### csv 읽기 저장

# %%
# 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("drive/My Drive/Colab Notebooks/youtube/agileML/titanic/data/train.csv")
# df = pd.read_csv("train.csv")

#dacon사이트 - 교육 - 타이타닉 - 데이터 다운로드

# %%
df.to_csv("drive/My Drive/Colab Notebooks/youtube/agileML/pandas/newfile2.csv")
# df = pd.to_csv("newfile.csv")

# %% [markdown]
# ### 기본 EDA

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass  ...  Fare Cabin  Embarked
# 890          891         0       3  ...  7.75   NaN         Q
#
# [1 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  ... -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# ### 데이터프레임과 시리즈

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
#하나의 컬럼(피처) 선택
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#두개 이상의 컬럼(피처) 선택
df[['Pclass','Fare']]
# Out:
#      Pclass     Fare
# 0         3   7.2500
# 1         1  71.2833
# 2         3   7.9250
# 3         1  53.1000
# 4         3   8.0500
# ..      ...      ...
# 886       2  13.0000
# 887       1  30.0000
# 888       3  23.4500
# 889       1  30.0000
# 890       3   7.7500
#
# [891 rows x 2 columns]

# %%
#카테고리별 카운트
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### 결측치

# %%
#결측치 확인
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#결측치 처리 (값 채우기, 열삭제, 행삭제)

# %%
#평균
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#Age 값 채우기
df['Age'] = df['Age'].fillna(df['Age'].mean())
# df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Cabin 열 삭제
df = df.copy()
df = df.drop('Cabin', axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
#Embarked 값 채우기
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])  #Embarked 최빈값

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### 범주형 데이터 처리

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
# 성별 원핫인코딩
df_sex = pd.get_dummies(df['Sex'])
df_sex.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df_encoding = pd.concat([df, df_sex], axis=1)

# %%
df_encoding.head(1)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked female  male
# 0            1         0       3  ...        S      0     1
#
# [1 rows x 13 columns]

# %%
df_encoding = df_encoding.drop('Sex', axis=1)

# %%
df_encoding.head(1)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked  female  male
# 0            1         0       3  ...        S       0     1
#
# [1 rows x 12 columns]

# %%
# Embarked 원핫인코딩
df_embarked = pd.get_dummies(df_encoding['Embarked'])
df_encoding = pd.concat([df_encoding, df_embarked], axis=1)
df_encoding = df_encoding.drop('Embarked', axis=1)

# %%
df_encoding.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  ...  male  C  Q  S
# 0            1         0       3  Braund, Mr. Owen Harris  ...     1  0  0  1
#
# [1 rows x 14 columns]

# %%
del df_sex, df_embarked

# %%
df_encoding['Ticket'].value_counts()
# Out:
# 347082               7
# CA. 2343             7
# 1601                 7
# 347088               6
# CA 2144              6
#                     ..
# 349241               1
# STON/O 2. 3101285    1
# 345763               1
# 349242               1
# 343120               1
# Name: Ticket, Length: 681, dtype: int64

# %%
df_encoding['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df_encoding.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  ...  male  C  Q  S
# 0            1         0       3  Braund, Mr. Owen Harris  ...     1  0  0  1
#
# [1 rows x 14 columns]

# %%
# 숫자로 처리가 어려운 행 삭제 PassengerId, Name, Ticket
df_encoding = df_encoding.drop('PassengerId', axis=1) #PassengerId 행 삭제
df_encoding = df_encoding.drop('Name', axis=1) #Name 행 삭제
df_encoding = df_encoding.drop('Ticket', axis=1) #Ticket 행 삭제

# %%
df_encoding.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  female  male  C  Q  S
# 0         0       3  22.0      1      0   7.2500       0     1  0  0  1
# 1         1       1  38.0      1      0  71.2833       1     0  1  0  0
# 2         1       3  26.0      0      0   7.9250       1     0  0  0  1
# 3         1       1  35.0      1      0  53.1000       1     0  0  0  1
# 4         0       3  35.0      0      0   8.0500       0     1  0  0  1

# %%
# 데이터 저장
df_encoding.to_csv("drive/My Drive/Colab Notebooks/youtube/agileML/pandas/train_encoding.csv")

# %% [markdown]
# ## 과제
# - 결측치 처리와 범주형 데이터 처리를 함수로 만들어 보세요
# - 가능하면 혼자서 해보고나서 아래 해답을 보세요!
#
#
#   [처리해야 할 것]
#   - 결측치 처리(Age, Cabin, Embarked)
#   - 범주형 데이터 처리(원핫인코딩:Sex, Embarked)
#   - PassengerId, Name, Ticket 행 삭제

# %%
# 원본 데이터 불러오기
train = pd.read_csv("drive/My Drive/Colab Notebooks/youtube/agileML/titanic/data/train.csv")

# %%
# 과제:전처리 함수
def preprocessing(df):
  # 이곳에 코드를 작성해주세요!(최종 리턴 값은 아래 df입니다)
  
  return df

# %%
# 함수 실행 및 head()값 출력
train_pre = preprocessing(train)
train_pre.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# 해답을 먼저 보진 마세요 ^^

# %%
# 과제 풀어 보시고 내려오는거죠? :)

# %%
# 꼭 한번은 해보고 확인해주세요!

# %% [markdown]
# ## 과제 해답

# %%
train = pd.read_csv("drive/My Drive/Colab Notebooks/youtube/agileML/titanic/data/train.csv")

def preprocessing(df):
  '''
  - 결측치 처리(Age, Cabin, Embarked)
  - 범주형 데이터 처리(원핫인코딩:Sex, Embarked)
  - PassengerId, Name, Ticket 행 삭제
  '''
  #결측치 처리
  df['Age'] = df['Age'].fillna(df['Age'].mean())  #age 평균값
  df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])  #Embarked 최빈값
  df = df.drop('Cabin', axis=1) #Cabin 행 삭제

  #범주형 데이터 처리 (원핫 인코딩 후 원본 컬럼은 삭제함)
  df_encoding = pd.get_dummies(df[['Sex','Embarked']])
  df = pd.concat([df, df_encoding], axis=1)
  df = df.drop('Sex', axis=1) #Sex 행 삭제 
  df = df.drop('Embarked', axis=1) #Embarked 행 삭제

  #승객번호, 이름, 티켓 삭제
  df = df.drop('PassengerId', axis=1) #Name 행 삭제
  df = df.drop('Name', axis=1) #Name 행 삭제
  df = df.drop('Ticket', axis=1) #Ticket 행 삭제

  return df


train_pre = preprocessing(train)
train_pre.head()
# Out:
#    Survived  Pclass   Age  SibSp  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         0       3  22.0      1  ...         1           0           0           1
# 1         1       1  38.0      1  ...         0           1           0           0
# 2         1       3  26.0      0  ...         0           0           0           1
# 3         1       1  35.0      1  ...         0           0           0           1
# 4         0       3  35.0      0  ...         1           0           0           1
#
# [5 rows x 11 columns]

# %% [markdown]
# **응원하겠습니다 !! 화이팅! **
